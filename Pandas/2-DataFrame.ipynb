# %%
import numpy as np
import pandas as pd

np.random.seed(101)
mydata = np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
my_index = ['CA','NY','AZ','TX']
mycolumns = ['Jan', 'Feb','Mar']
DataFrame = pd.DataFrame(mydata)
DataFrame
# Out:
#     0   1   2
# 0  95  11  81
# 1  70  63  87
# 2  75   9  77
# 3  40   4  63

# %%
DataFrame = pd.DataFrame(mydata,my_index,mycolumns)
DataFrame
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# AZ   75    9   77
# TX   40    4   63

# %% [markdown]
# #### pwd = print word directory

# %%
pwd
# Out:
# 'd:\\Tutorials and Content\\Python\\2. Python - Intermediate\\Pandas'

# %% [markdown]
# #### for listing the files in the current directory

# %%
ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 7A22-B896
#
#  Directory of d:\Tutorials and Content\Python\2. Python - Intermediate\Pandas
#
# 03/23/2024  02:54 PM    <DIR>          .
# 03/23/2024  02:16 PM    <DIR>          ..
# 03/23/2024  02:34 PM             6,533 1-series.ipynb
# 03/23/2024  02:55 PM             5,438 2-DataFrame.ipynb
# 01/28/2020  12:58 AM            18,752 tips.csv
#                3 File(s)         30,723 bytes
#                2 Dir(s)  179,436,969,984 bytes free

# %%
DataFrame = pd.read_csv('tips.csv')
DataFrame
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
DataFrame.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
DataFrame.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
DataFrame.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
DataFrame.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 236    Matthew Myers  3543676378973965    Sat5032
# 237     Thomas Brown  4284722681265508    Sat2929
# 238   Kimberly Crane      676184013727    Sat9777
# 239    Michael Avila  5296068606052842    Sat2657
# ...

# %%
DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
DataFrame.describe()
# mean is the average value.
# std = standard deviation which is
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
DataFrame.describe().transpose()
# mean is the average value.
# std = standard deviation which is
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
DataFrame['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
mycolumns_1 = ['total_bill','tip']
DataFrame[mycolumns_1]  
# or we can use 'DataFrame[['total_bill','tip']]'
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
DataFrame[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
DataFrame['tip'] + DataFrame['total_bill']
# Out:
# 0      18.00
# 1      12.00
# 2      24.51
# 3      26.99
# 4      28.20
#        ...
# 239    34.95
# 240    29.18
# 241    24.67
# 242    19.57
# 243    21.78
# Length: 244, dtype: float64

# %% [markdown]
# How to add a column? we add it like this:

# %%
DataFrame['percentage'] = np.round(100 * (DataFrame['tip'] / DataFrame['total_bill']),2)
DataFrame.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.94
# 1      Douglas Tucker  4478071379779230    Sun4608       16.05
# 2      Travis Walters  6011812112971322    Sun4458       16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.98
# 4        Tonya Carter  4832732618637221    Sun2251       14.68

# %% [markdown]
# ### For removing a column from our data: (cleaning)

# %%
Dropped_df = DataFrame.drop('sex',axis=1)
Dropped_df
# Out:
#      total_bill   tip smoker   day    time  size  price_per_person  \
# 0         16.99  1.01     No   Sun  Dinner     2              8.49
# 1         10.34  1.66     No   Sun  Dinner     3              3.45
# 2         21.01  3.50     No   Sun  Dinner     3              7.00
# 3         23.68  3.31     No   Sun  Dinner     2             11.84
# 4         24.59  3.61     No   Sun  Dinner     4              6.15
# ..          ...   ...    ...   ...     ...   ...               ...
# 239       29.03  5.92     No   Sat  Dinner     3              9.68
# 240       27.18  2.00    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75     No   Sat  Dinner     2              8.91
# 243       18.78  3.00     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  percentage
# 0    Christy Cunningham  3560325168603410    Sun2959        5.94
# ...

# %%
indext_df = DataFrame.set_index("Payment ID")
indext_df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number  percentage
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410        5.94
# ...

# %%
# How to reset an index? 
DataFrame.reset_index()
# Out:
#      index  total_bill   tip     sex smoker   day    time  size  \
# 0        0       16.99  1.01  Female     No   Sun  Dinner     2
# 1        1       10.34  1.66    Male     No   Sun  Dinner     3
# 2        2       21.01  3.50    Male     No   Sun  Dinner     3
# 3        3       23.68  3.31    Male     No   Sun  Dinner     2
# 4        4       24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...         ...   ...     ...    ...   ...     ...   ...
# 239    239       29.03  5.92    Male     No   Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242    242       17.82  1.75    Male     No   Sat  Dinner     2
# 243    243       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID  \
# 0                8.49  Christy Cunningham  3560325168603410    Sun2959
# ...

# %%
DataFrame.iloc[0]
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# percentage                        5.94
# Name: 0, dtype: object

# %%
DataFrame.iloc[0:4]
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
#
#            Payer Name         CC Number Payment ID  percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.94
# 1      Douglas Tucker  4478071379779230    Sun4608       16.05
# 2      Travis Walters  6011812112971322    Sun4458       16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.98

# %%
DataFrame.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.94
# 1      Douglas Tucker  4478071379779230    Sun4608       16.05
# 2      Travis Walters  6011812112971322    Sun4458       16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.98
# 4        Tonya Carter  4832732618637221    Sun2251       14.68

# %%
DataFrame.loc['Sun2959']
