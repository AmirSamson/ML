# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# How to group some data?
# -----
# we should use GroupBy()

# %%
df['model_year'].value_counts()

df.groupby(['model_year'],['cylinders']).mean()['mpg']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2260\150853494.py in ?()
#       1 df['model_year'].value_counts()
#       2
# ----> 3 df.groupby(['model_year'],['cylinders']).mean()['mpg']
#
# c:\Users\98930\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8842         observed: bool | lib.NoDefault = lib.no_default,
#    8843         dropna: bool = True,
#    8844     ) -> DataFrameGroupBy:
#    8845         if axis is not lib.no_default:
# -> 8846             axis = self._get_axis_number(axis)
#    8847             if axis == 1:
#    8848                 warnings.warn(
#    8849                     "DataFrame.groupby with axis=1 is deprecated. Do "
#
# c:\Users\98930\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     549     @classmethod
# ...
